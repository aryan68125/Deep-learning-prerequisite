# %% [markdown]
# # Python's inner Working

# %% [markdown]
# test.py ---> Byte code ---> Python VM (Virtual Machine) <br>
# - First we have to use python interpreter and give that interpreter our python script that we want to run.
# - The Generated byte codes are mostly hidden but when you import classes from other python modules then these byte codes are easily visible. Its mostly present inside the __pychache__ folder of your package. I have mostly used django and fastAPi and I have seen these __pychache__ folders being created as we run our server and our python code start getting executed one by one.
# - .pyc is the compiled python code (Frozen binaries) . These fiels are some what similar to java byte codes but are fundamentally different from them.
#   - The next time the script runs, Python can skip the compilation step and load the .pyc file directly — faster startup.
#   - If nothing in the source file has changed, Python reuses the .pyc file.
#
# ### Difference between Java byte code and Python byte code
# | Feature               | Java Bytecode (`.class`)                | Python Bytecode (`.pyc`)                        |
# | --------------------- | --------------------------------------- | ----------------------------------------------- |
# | 🔄 Compiled From      | `.java` source files                    | `.py` source files                              |
# | 📁 Output File        | `.class` files                          | `.pyc` files (in `__pycache__/`)                |
# | 💻 Execution Platform | Java Virtual Machine (JVM)              | Python Virtual Machine (PVM)                    |
# | 🌐 Portability        | Very high – runs on any JVM             | Limited – version-dependent on Python           |
# | ⚙️ Compilation Step   | Explicit (`javac MyClass.java`)         | Implicit (on first import or run of `.py` file) |
# | 🧠 Optimization Level | Can be optimized (`-O`) with JIT in JVM | Basic – no runtime optimization                 |
# | 🔁 Reusability        | Reusable across platforms via JVM       | Tied to specific Python version (e.g. CPython)  |
# | 📦 Packaging          | Can be bundled into `.jar` files        | Not usually bundled – regenerated on demand     |

# %% [markdown]
# ### NOTE:
# - Python virtual machine is the one that actually runs your code under the hood.
# - Just because python is generating byte code doesn't mean it is a compiled time language no! Python is an interpreted language.
# - Python byte code .pyc file runs faster than the python program because all the checks related to syntax,  Parsing etc. are mostly done.
# - Python uses a diffing algorithm to tell if there are any changes made in the script based on what is present in the .pyc file generated from that script. Then python puts the changes made in the script in that .pyc file. Whole python byte code is not generated only new changes are put inside of it.
# - When generating a .pyc Python bytecode file, the Python version plays an important role because the .pyc file is specific to the version of Python that created it, and it may not be compatible with other versions during execution.
# - These .pyc files are only visible when you import something
# - .pyc file (Python Byte code) is not a machine code. They are not the insttuctions that can be fed directly fed in your intel or apple arm processors.
# - .pyc is Python sepcific interpretation.

# %% [markdown]
# ## Python Virtual Machine PVM
# The Python Virtual Machine (PVM) is the runtime engine that interprets and executes Python bytecode (.pyc files). It’s a part of the Python interpreter and plays a central role in Python's execution model.
# #### Working of PVM:
# - You write Python code (.py file).
# - The Python compiler converts that code into bytecode (.pyc file), an intermediate, low-level representation.
# - The PVM reads this bytecode and executes it line by line.
# - Since PVM executes the .pyc file line by line hence python is called an interpreted language
# - PVM can accept .pyc file or directly .py file which is essentially your python script. That's why .pyc file is doesn't get generated for the top level file i.e if a folder has only one python file .pyc file will not get generated.

# %% [markdown]
# # Python shell

# %% [markdown]
# - If you are writing your code in a python shell then your code will not be saved.
# - Python shell runs the code immediately after pressing enter button.
# - Python shell is mostly used to understand code if you are facing difficulties undertanding how that particular code works.

# %% [markdown]
# ### Executing some programs directly in python shell
# NOTE : Jupyter notebook can simulate python shell if you use this '>>>' in your code snippit

# %% [markdown]
# #### Get current working directory in python shell

# %%
>>> import os
>>> os.getcwd()
# Out:
# '/home/aditya/github/Deep-learning-prerequisite/python_basics/python_inner_working'

# %% [markdown]
# #### Printing characters in the string "coffee" in different lines

# %%
>>> string_input = "coffee"
>>> for character in string_input:
        print(character, "\n")
# Out:
# c
#
# o
#
# f
#
# f
#
# e
#
# e

# %% [markdown]
# #### Get platform related info

# %%
>>> import sys
>>> sys.platform
# Out:
# 'linux'

# %% [markdown]
# ### How modules work when imported vs. executed directly.

# %% [markdown]
# #### Import statements
# - If python knows where to look then you can directly write import
# - Python by default looks from the file to be imported in the current directory.

# %%
import python_inner_working
# Out:
# Test program

# %% [markdown]
# #### Explanation :
# - ```print(f"Test program")``` runs --> This is a top level code so it always runs.
# - The ```if __name__ == "__main__"``` block does NOT run when the module is imported. That block only executes when you run the script directly using ```python3 python_inner_working.py``` in your terminal.
#
# #### Why driver_fun() is not called on import?
# - Because it’s inside this block ```if __name__ == "__main__": ``` and during import ```__name__``` is not ```"__main__"```, it's actually ```"python_inner_working"```.
#
# #### To print the welcome message you will have to do this instead

# %%
from python_inner_working import Main
obj = Main()
obj.driver_fun()
# Out:
# Hello Aditya!

# %% [markdown]
# #### Now suppose I want to print a welcome message but I want a different name in it then

# %%
from python_inner_working import Main
obj = Main()
result = obj.print_welcome_message("Rollex")
result
# Out:
# 'Hello Rollex!'

# %% [markdown]
# ### Suppose I made changes in python_inner_working.py file as shown below
# ``` python
# print(f"Test program")
#
# from utility_import_test import TestClass
#
# class Main(TestClass):
#     def driver_fun(self):
#         result = self.print_welcome_message("Aditya")
#         print(result)
#
# coffee_one = "Expresso"
# coffee_two = "Black"
# coffee_three = "Cappuchino"
#
# if __name__ == "__main__":
#     obj = Main()
#     obj.driver_fun()
# ```
# <br>

# %% [markdown]
# #### Now If try to access cofee_one will I be able to access it?

# %%
import python_inner_working
python_inner_working.coffee_one
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 import python_inner_working
# ----> 2 python_inner_working.coffee_one
#
# AttributeError: module 'python_inner_working' has no attribute 'coffee_one'

# %% [markdown]
# #### Variables in python are also known as attributes

# %% [markdown]
# #### So why are these attributes not available here ? I have already made changes in the file
# - When I run:
#     ```python
#         import python_inner_working
#         python_inner_working.coffee_one
#     ```
# - I expect the variable ```coffee_one``` to be available, but I am getting an error. The reason lies in Stale import in Jupyter (Caching)
# #### Stale Import in Jupyter (Caching)
# When you import a module in Jupyter, it gets cached in memory. If you edit the .py file afterward, those changes don’t reflect unless you explicitly reload the module. <br>
# So even though your file now has coffee_one, the version already loaded in Jupyter doesn’t.

# %%
import python_inner_working
import importlib
# Reload the module to apply latest file changes
importlib.reload(python_inner_working)

# Now it should work
python_inner_working.coffee_one
# Out:
# Test program
# 'Expresso'

# %% [markdown]
# #### As you can see not the code works like a charm

# %% [markdown]
# ### Explaination:

# %% [markdown]
# When I am working in Jupyter Notebook (or any long-running Python session), modules are cached the first time you import them. If I later edit the module's .py file outside the notebook (like in VS Code or a text editor), those changes won’t automatically show up when I am re-import it. <br>
# #### Why ```import python_inner_working``` alone is not enough
# After editing the file ```python_inner_working.py```, Python will use the old cached version. It won’t re-read the file from disk.
# #### ```importlib.reload()```: The Fix
# To force python to reload the updated file from the disk use :
# ```python
#     import importlib
#     importlib.reload(python_inner_working)
# ```
# - Reads the updated version of ```python_inner_working.py```
# - Re-executes the module’s code
# - Updates functions, classes, and variables defined in the module

# %% [markdown]
# # Python language foundation

# %% [markdown]
# ## Mutable vs Immutable

# %% [markdown]
# In python everything is an object
# ### Mutable objects :
# - list
# - dict
# - set
# - bytearray
# - user-defined objects
#
# ### Immutable objects :
# - int
# - float
# - str
# - tuple
# - frozenset
# - bytes

# %% [markdown]
# ### Immutable objects

# %%
username = "Aditya"
print(f"username ===> {username}")
username = "Coffee"
print(f"username ===> {username}")
# Out:
# username ===> Aditya
# username ===> Coffee

# %% [markdown]
# #### Huh? Intresting
# #### But just now in the docs I read that strings are Immutable so what gives ?
# #### How did username changed from "Aditya" to "coffee" ?

# %% [markdown]
# - Like we know that in python everything is an object
# - When we say that ```username = "Hitesh"``` then a memory reference is created in computer's memory and inside of that memory reference the string ```"Hitesh"``` will be kept. One thing to note is everything in python is created as an object inside the memory.
# - This string reference created inside the memory is immutable. You can't change this reference in python.
# - Now When I reassigned ```username = Coffee``` then one more memory reference is created in computer's memory and inside that memory reference the string ```"Coffee"``` is kept, and just like before this will also be an object.
# - Now earlier ```username``` was pointing towards the memory reference where string ```"Hitesh"``` was kept and after I reassigned ```username``` to ```Coffee``` the same ```username``` then started pointing towards the memory reference where ```coffee``` is kept.
# ![varibles_memory_reference_1.png](attachment:0d502464-5536-42af-a204-91b74058e4b6.png)
# ![varibles_memory_reference_2.png](attachment:d6d18d12-0dae-40d4-86fd-f9a9f62665d1.png)
# - As you can see I tried to show in the diagram that only the reference of the variable has changed not the actual reference of the string ```"Hitesh"``` in the memory. Hence making string immutable in nature.
# - Python has a garbage collector which will collect all the memory reference which are not being used and all those references will be deleted from the memory here in this case it's ```"Aditya"``` hence the sting ```"Aditya``` will be deleted from the memory.
# - ```username``` is a variable which is also present in the computer's memory but unlike the string values it is present in the namespace object like ```globals()``` or ```locals()```. This is a label (or name) stored in a namespace — which is essentially a Python dictionary.

# %% [markdown]
# #### Example 2:

# %%
x = 10
y = x
print(f"y ===> {y}")
x = 15
print(f"x = 15 ===> {x}")
print(f"y ===> {y}")
# Out:
# y ===> 10
# x = 15 ===> 15
# y ===> 10

# %% [markdown]
# ##### Explanation:
# ```x = 10``` means create a memory reference in the memory and keep the value ```10``` there and then make the variable x point towards that memory reference.
# ![x_is_equal_to_10.png](attachment:c9834d8a-e467-456d-b9a4-0c12e4e61b1d.png) <br>
# ```x = y``` means that y should also point to the value ```10```. Now both ```x``` and ```y``` variables point towards the same value in the memory reference which in this case is ```10```.
# ![x_is_equal_to_y.png](attachment:9781351b-78e5-4858-877b-4b4ed2d9312f.png) <br>
# ```x = 15``` means that now x should point towards a new memory reference where value ```15``` is kept.
# ![x_is_equal_to_15.png](attachment:fe7ed636-e242-4d92-9b5f-0a1b105cbf29.png) <br>
# Notice while x is pointing towards the new memory reference but y is still pointing towards the memory reference where value ```10``` is kept
