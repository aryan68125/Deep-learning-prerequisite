# %%
# %pip install psycopg2-binary
# Out:
# ...
#   Using cached psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Using cached psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# Database configuration
db_config = {
    "host": "localhost",       # or your IP/domain
    "port": 5432,
    "database": "inquiry_app",
    "user": "postgres",
    "password": "ilovemymom"
}

try:
    # Connect to PostgreSQL
    connection = psycopg2.connect(**db_config)
    cursor = connection.cursor()

    # Sample query
    result = cursor.execute("""
    SELECT email_id,emp_code,created_by FROM employee_app_employeemaster;
    """)
    temp_data = {}
    db_version = cursor.fetchall()
    result = {
        "xyz": [
            {"email": email, "emp_code": emp_code, "created_by": created_by}
            for email, emp_code, created_by in db_version
        ]
    }
             
    print("🟢 Connected! PostgreSQL version:", result)

except Exception as e:
    print("🔴 Error connecting to PostgreSQL:", e)

finally:
    if 'cursor' in locals():
        cursor.close()
    if 'connection' in locals():
        connection.close()
        print("🔌 PostgreSQL connection closed.")
# Out:
# 🟢 Connected! PostgreSQL version: {'xyz': [{'email': 'tttt@tttt.ttt', 'emp_code': 'ttt-001', 'created_by': 3}, {'email': 'hasbdshdbd@mail.com', 'emp_code': '788aaa', 'created_by': 306}, {'email': 'abc@mail.com', 'emp_code': 'COM-561', 'created_by': 1}, {'email': 'kuugbjkn@dxfxgtu.bui', 'emp_code': '6569/*/-6+6', 'created_by': 3}, {'email': 'ssdf@fgdgdf.fdgsfd', 'emp_code': 'COM-618', 'created_by': 1}, {'email': 'katsuki@gmail.com', 'emp_code': None, 'created_by': 1}, {'email': 'sdfs34@fdg.fd', 'emp_code': 'COM-619', 'created_by': 1}, {'email': 'fnggfjytjhuky4@erur.wgrer', 'emp_code': 'qfwe-456s5', 'created_by': 13}, {'email': 'akash@gmail.com', 'emp_code': 'Akash-002', 'created_by': 1}, {'email': 'james@gmail.com', 'emp_code': 'James-007', 'created_by': 1}, {'email': 'ayush@gmail.com', 'emp_code': 'Ayush-1', 'created_by': 1}, {'email': 'aadya@gmail.com', 'emp_code': 'aadya-1', 'created_by': 1}, {'email': 'asdanwin@mail.com', 'emp_code': '8984sss', 'created_by': 306}, {'email': 'tempes
# ...
