# %% [markdown]
# # Crosstab in pandas
# ```.crosstab()``` function allows you to compute a frequency table of two or more variables, which summarizes the distribution of values in the data and provides insightes into the relationships between the variables. It is a type of table in a matrix format that displays the multivariate frequency distribution of variables. They are heavily used in survey research, business, intelligence, engineering and scientific research.
