# %%
# %pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Using cached psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Using cached psycopg2_binary-2.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# Database configuration
db_config = {
    "host": "localhost",       # or your IP/domain
    "port": 5432,
    "database": "inquiry_app",
    "user": "postgres",
    "password": "ilovemymom"
}

try:
    # Connect to PostgreSQL
    connection = psycopg2.connect(**db_config)
    cursor = connection.cursor()

    # Sample query
    result = cursor.execute("""
    SELECT email_id,emp_code,created_by FROM employee_app_employeemaster;
    """)
    temp_data = {}
    db_version = cursor.fetchall()
    result = {
    "xyz": [
            {"email": email, "emp_code": emp_code, "created_by": created_by}
            for email, emp_code, created_by in db_version
        ]
    }
             
    print("🟢 Connected! PostgreSQL version:", result)

except Exception as e:
    print("🔴 Error connecting to PostgreSQL:", e)

finally:
    if 'cursor' in locals():
        cursor.close()
    if 'connection' in locals():
        connection.close()
        print("🔌 PostgreSQL connection closed.")
# Out:
# 🟢 Connected! PostgreSQL version: [('tttt@tttt.ttt', 'ttt-001', 3), ('hasbdshdbd@mail.com', '788aaa', 306), ('abc@mail.com', 'COM-561', 1), ('kuugbjkn@dxfxgtu.bui', '6569/*/-6+6', 3), ('ssdf@fgdgdf.fdgsfd', 'COM-618', 1), ('katsuki@gmail.com', None, 1), ('sdfs34@fdg.fd', 'COM-619', 1), ('fnggfjytjhuky4@erur.wgrer', 'qfwe-456s5', 13), ('akash@gmail.com', 'Akash-002', 1), ('james@gmail.com', 'James-007', 1), ('ayush@gmail.com', 'Ayush-1', 1), ('aadya@gmail.com', 'aadya-1', 1), ('asdanwin@mail.com', '8984sss', 306), ('tempest@email.com', None, 1), ('ritesh@gmail.com', 'Ritesh-6969', 1), ('britania@gmail.com', 'BR-215', 1), ('vibhuti@yahoo.com', 'Vibhuti-001', 1), ('ehwqk@hwqejkl.lhqjl', 'COM-555', 1), ('vijay@email.com', 'vijai-005', 189), ('birla@gmail.com', 'AD-226', 1), ('fawsgdrt@nbfjuhb.iqinfinirte.in', '00100', 3), ('testing@email.com', 'testing', 1), ('test@gmail.com', 'test-401', 1), ('qqweeq@ertert.yutytu', 'eq-15', 377), ('kakashi@gmail.com', 'KH-001', 233), ('asd@mail.com', 'COM-556', 1), ('s.b@email.com', 'S-208', 231), ('victoria@email.com', 'VN-003', 230), ('sdff24sfdfdfdf323ssd@mail.com', 'COM-788', 1), ('keyur0322222222@gmail.com', 'COM-628', 1), ('keyu424r0324@gmail.com', 'COM-632', 1), ('v.d@email.com', 'VD-218', 231), ('elektra@email.com', 'ER-215', 231), ('valentina@gmail.com', 'V-001', 231), ('gg@email.com', 'gg-300', 229), ('keyur21212120324@gmail.com', 'COM-636', 1), ('vaibhav.tailor@iqinfinite.inte', 'COM-624', 1), ('dynamite@email.com', 'D-911', 232), ('aryan123@gmail.com', 'AR-310', 336), ('rolex@email.com', 'R-997', 232), ('mia@email.com', 'M-001', 231), ('vineeta@email.co', 'vineeta-001', 1), ('vivek@gmail.com', 'vivek-001', 1), ('vikrant@gmail.com', 'vikrant-001', 1), ('vaishali@gmail.com', 'vaishali-001', 1), ('vinod@gmail.com', 'vinod-001', 1), ('dilpreet.singh@email.com', 'DS-001', 377), ('force@email.com', 'FO-212', 1), ('asd@gmail.com', 'asd-1', 1), ('pop@gmail.com', 'POP', 1), ('korea@email.com', 'COM-362', 1), ('akasha@gmail.com', 'akasha-001', 1), ('narayan.joshi@iqinfinite.in', 'NA-227', 1), ('vineet@email.com', 'VS-224', 229), ('shockwave@email.com', 'S-360', 232), ('jjjj@email.com', 'jjjj', 377), ('testing.update@email.com', 'COM-364', 1), ('narendra@gmail.com', 'N-51', 189), ('fds@fdg.dfg', 'TEST-01', 656), ('lawrence.vishnoi@gmail.com', 'lawrence-001', 1), ('tanuj@email.com', 'tanuj-001', 189), ('artillery@gmail.com', 'A-280', 232), ('vikrant.singh@email.com', 'VS-220', 229), ('yrtyrt@yrtyt.yrtyrt', 'YR-351', 1), ('eshan@gmail.com', 'Eshan-001', 1), ('keyur032asdd4@gmail.com', 'COM-557', 1), ('alice.smith@gmail.com', 'alice-001', 189), ('emailtestcompany@email.com', 'COM-365', 1), ('etwrwer@dsfjk.sdfsdsadsdfdg', 'ppp-20d4d', 663), ('keyur.patel32@iqinfinite.in', 'COM-371', 1), ('aditya.kumar45@iqinfinite.in', 'AD-200', 367), ('aryan65@gmail.com', 'AR-001', 336), ('ahdbsadasdad@mail.com', '89785adadd', 306), ('abc101@mail.com', 'COM-563', 1), ('keyur.patel8@iqinfinite.in', None, 1), ('hari@email.com', 'HR-102', 229), ('asdasdawww@mail.com', '87dd87d', 306), ('ayushi@gmail.com', 'Ayushi-002', 1), ('weqweq@weqweq.we', 'WE-329', 1), ('akash@email.com', 'Akash-001', 1), ('vikram2@gmail.com', 'vikram=002', 1), ('ballistic@email.com', 'B-1000', 232), ('shotgun@email.com', 'S-012', 232), ('neha11osrgi@gmail.com', '155', 3), ('asdawrfv@mail.com', 'd87987', 306), ('knight.fury@email.com', 'KF-072', 232), ('mrmrmrmr@mrmr.rmr', 'COM-603', 1), ('shellshock@email.com', 'SS-555', 232), ('vikram.raina@email.com', 'VR-223', 306), ('vivek@email.com', 'VI-228', 1), ('vaibhav@email.com', 'abishek', 189), ('radha1swami@g2maill.co', 'R-006', 1), ('anand@email.com', 'MA-211', 1), ('kanishka@gmail.com', 'Kanishka-002', 1), ('aditya.kumar32@iqinfinite.in', 'COM-366', 1), ('re@gmail.com', 'RO-213', 1), ('hazel@email.com', 'HM-216', 231), ('natasha@gmail.com', 'N-001', 231), ('keyur.patel44@iqinfinite.in', 'KY-100', 367), ('vikram.bhatia@email.com', 'VB-221', 229), ('kkkk@kkkk.kkkk', 'kkkk', 377), ('indri@email.com' ...
# 🔌 PostgreSQL connection closed.
