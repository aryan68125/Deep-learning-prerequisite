# %% [markdown]
# # Pandas

# %%
import pandas as pd
# df = pd.read_csv("/home/aditya/github/Deep-learning-prerequisite/pandas/dataset/nyc_weather.csv") # for office pc path 
df = pd.read_csv("/home/machine_learning/github/Deep-learning-prerequisite/pandas/dataset/nyc_weather.csv") # for macbook home pc
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# ## What is the maximum temperature?

# %%
df["Temperature"].max()
# Out:
# 50

# %% [markdown]
# ## On what dates the it rained in the city?

# %%
df["EST"][df['Events']=="Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %% [markdown]
# ## On what dates it Fog-Snow in the city?

# %%
df["EST"][df["Events"]=="Fog-Snow"]
# Out:
# 16    1/17/2016
# 22    1/23/2016
# Name: EST, dtype: object

# %% [markdown]
# ## On what dates it Snowed in the city?

# %%
df["EST"][df["Events"]=="Snow"]
# Out:
# 17    1/18/2016
# 21    1/22/2016
# 23    1/24/2016
# Name: EST, dtype: object

# %% [markdown]
# ## What is my average wind speed?

# %%
df["WindSpeedMPH"].mean(axis=0)
# Out:
# 6.892857142857143

# %% [markdown]
# ### Explanation: df["WindSpeedMPH"].mean(axis=0)
# - df is a Pandas DataFrame.
# - df["WindSpeedMPH"] selects a single column — so you get a Pandas Series.
# - .mean(axis=0) computes the mean (average) of the values in that Series.
# - axis=0 is optional here and doesn’t affect the result because a Series is 1-dimensional.
# ### You can read this post in stackoverflow
# https://stackoverflow.com/questions/31037298/pandas-get-column-average-mean

# %%
# prove that axis = 0 is not required here
df["WindSpeedMPH"].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# #### Huh? intresting both the results are the same in case where axis=0 and where axis is not provided in the mean function.

# %% [markdown]
# ## Operations in dataFrame
# - Here is the link to the documentation where all the operations are being mentioned.
# - https://pandas.pydata.org/docs/reference/index.html

# %% [markdown]
# ## Calculating average of Temperature, DewPoint, Humidity, Sea Level PressureIn, VisibilityMiles columns in the data frame.

# %%
df[["Temperature", "DewPoint", "Humidity", "Sea Level PressureIn", "VisibilityMiles"]].mean()
# Out:
# Temperature             34.677419
# DewPoint                17.838710
# Humidity                51.677419
# Sea Level PressureIn    29.992903
# VisibilityMiles          9.193548
# dtype: float64

# %% [markdown]
# ## Calculate the count of data present in a column in the data frame

# %%
df[["Temperature"]].count()
# Out:
# Temperature    31
# dtype: int64

# %% [markdown]
# ## Calculate the count of data in the selected table

# %%
df[["Temperature","DewPoint","Humidity"]].mean()
# Out:
# Temperature    34.677419
# DewPoint       17.838710
# Humidity       51.677419
# dtype: float64

# %% [markdown]
# ## Calculate standard deviation
# - Standard Deviation (σ) is a statistical measure that tells you how spread out the values in a dataset are from the mean (average)
# - If the values are close to the mean, the standard deviation is small.
# - If the values are spread out, the standard deviation is large..
# ## Why standard deviation is important
# - Detecting anomalies and outliers:
#   - If a data point is several standard deviation away from the mean, it's likely and outlier.
#   - It is used for Fraud detection, quality control, sensor anomalies.
# - Comparing performance consistency:
#   - Let's say I have to analyze the test score of two students over several exams:
#   - Student A has more consistent performance.
#   - Student B has higher variability.
#   - Useful for: HR appraisals, academic evaluations, product quality
# - Risk assesment in Finance:
#   - Standar deviation is often used as a measure of risk in investment returns.
#   - Higher standard deviation means more unpredictable returns and higher risks.
#   - Useful for portfolio management, stock analysis.
# - Understanding spread in distributions:
#   - You can visualize it using histogram + standard ranges to understand how data clusters around the mean

# %%
df["Temperature"].std()
# Out:
# 7.639315400279416

# %% [markdown]
# ## Calculate standard deviation of multiple selected columns

# %%
df[["Temperature","DewPoint","Humidity"]].std()
# Out:
# Temperature     7.639315
# DewPoint       11.378626
# Humidity       11.634395
# dtype: float64

# %% [markdown]
# ## Calculate min

# %%
df["Temperature"].min()
# Out:
# 20

# %% [markdown]
# ## Calculate min of multiple selected columns

# %%
df[["Temperature","DewPoint","Humidity"]].min()
# Out:
# Temperature    20
# DewPoint       -3
# Humidity       33
# dtype: int64

# %% [markdown]
# ## Calculate the max

# %%
df["Temperature"].max()
# Out:
# 50

# %% [markdown]
# ## Calculate the max of multiple selected columns

# %%
df[["Temperature", "DewPoint", "Humidity"]].max()
# Out:
# Temperature    50
# DewPoint       46
# Humidity       78
# dtype: int64

# %% [markdown]
# ## Calculate the max 25%

# %%
df["Temperature"].quantile(0.25)
# Out:
# 29.0

# %% [markdown]
# ## Calculate the max 25% for multiple selected columns

# %%
df[["Temperature", "DewPoint", "Humidity"]].quantile(0.25)
# Out:
# Temperature    29.0
# DewPoint       10.0
# Humidity       44.5
# Name: 0.25, dtype: float64

# %% [markdown]
# ### Explanation:
# - .quantile is a function that takes in a value in decimal and then calculates the percentage of the columns selected in df[]

# %% [markdown]
# ## To get count,mean,std,min and max all at once in data frame you can use .describe() function

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %% [markdown]
# ## Data Cleaning
# - The process of cleaning messy data is called data munging or data wrangling.

# %% [markdown]
# ### Result before data cleaning

# %%
df["WindSpeedMPH"].mean()
# Out:
# 6.892857142857143

# %% [markdown]
# ### Result after data cleaning

# %%
df.fillna(0, inplace=True)
df["WindSpeedMPH"].mean()
# Out:
# 6.225806451612903

# %% [markdown]
# ### Show Nan in df before cleaning

# %%
print(df["WindSpeedMPH"].isna().sum())
# Out:
# 0

# %% [markdown]
# ### Show Nan in df after clearning

# %%
df.fillna(0, inplace=True)
print(df["WindSpeedMPH"].isna().sum())
# Out:
# 0

# %% [markdown]
# ## Dataframe is a main object in Pandas it is used to represent data with rows and columns (tabular or excel spreadsheet like data)

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# ## Create a dataframe using python dictionary

# %%
weather_data = {
    "day":["1/1/2017","1/2/2017","1/3/2017","1/4/2017","1/5/2017","1/6/2017"],
    "temperature":[32,35,28,24,32,31],
    "windspeed":[6,7,2,7,4,2],
    "event":["Rain","Sunny","Snow","Snow","Rain","Sunny"]
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %% [markdown]
# ## Get the shape of the dataframe

# %%
df.shape
# Out:
# (6, 4)

# %% [markdown]
# ## Get all the events in dataframe

# %%
df["event"]
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %% [markdown]
# ## Get the type of a column in a df

# %%
type(df["event"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Get the type of a cell data in the event column in a df

# %%
type(df["event"][0])
# Out:
# str

# %% [markdown]
# ## Change the index number from integer number generated by the dataframe to the date present in the EST column of the dataframe.

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index("day",inplace=True)
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %% [markdown]
# #### df.loc[...]:
# - .loc[...] is used to access a group of rows and columns by labels or boolean array.
# - It works with labels, not integer positions.

# %%
df.loc["1/4/2017"]
# Out:
# temperature      24
# windspeed         7
# event          Snow
# Name: 1/4/2017, dtype: object

# %% [markdown]
# #### df.reset_index(inplace=True):
# - reset_index() — creates a new DataFrame with the index reset to the default (0, 1, 2, ...).
# - inplace=True — applies the change directly to df, instead of returning a new DataFrame.

# %%
df.reset_index(inplace=True)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.set_index("event",inplace=True)
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.loc["Snow"]
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %%
df.reset_index(inplace=True)
df
# Out:
#    event       day  temperature  windspeed
# 0   Rain  1/1/2017           32          6
# 1  Sunny  1/2/2017           35          7
# 2   Snow  1/3/2017           28          2
# 3   Snow  1/4/2017           24          7
# 4   Rain  1/5/2017           32          4
# 5  Sunny  1/6/2017           31          2

# %% [markdown]
# #### df[2:5]:
# - df[2:5] will select the rows from 2 to (5-1) i.e 4.

# %%
df[2:5]
# Out:
#   event       day  temperature  windspeed
# 2  Snow  1/3/2017           28          2
# 3  Snow  1/4/2017           24          7
# 4  Rain  1/5/2017           32          4

# %% [markdown]
# #### Print the columns of a dataframe.

# %%
df.columns
# Out:
# Index(['event', 'day', 'temperature', 'windspeed'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %% [markdown]
# ## Type of dataframe

# %%
type(df["event"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Only print the columns specified in the code.

# %%
df[['day','event','temperature']]
# Out:
#         day  event  temperature
# 0  1/1/2017   Rain           32
# 1  1/2/2017  Sunny           35
# 2  1/3/2017   Snow           28
# 3  1/4/2017   Snow           24
# 4  1/5/2017   Rain           32
# 5  1/6/2017  Sunny           31

# %% [markdown]
# ### Operations in pandas

# %% [markdown]
# #### Greater than and Grater than equal to

# %%
df[df.temperature>32]
# Out:
#    event       day  temperature  windspeed
# 1  Sunny  1/2/2017           35          7

# %%
df[df.temperature>=32]
# Out:
#    event       day  temperature  windspeed
# 0   Rain  1/1/2017           32          6
# 1  Sunny  1/2/2017           35          7
# 4   Rain  1/5/2017           32          4

# %% [markdown]
# #### Less than and less than equal to

# %%
df[df.temperature < 32]
# Out:
#    event       day  temperature  windspeed
# 2   Snow  1/3/2017           28          2
# 3   Snow  1/4/2017           24          7
# 5  Sunny  1/6/2017           31          2

# %%
df[df.temperature <= 32]
# Out:
#    event       day  temperature  windspeed
# 0   Rain  1/1/2017           32          6
# 2   Snow  1/3/2017           28          2
# 3   Snow  1/4/2017           24          7
# 4   Rain  1/5/2017           32          4
# 5  Sunny  1/6/2017           31          2

# %% [markdown]
# #### If I want to get the row where temperature was maximum

# %%
df[df["temperature"] == df["temperature"].max()]
# Out:
#    event       day  temperature  windspeed
# 1  Sunny  1/2/2017           35          7

# %% [markdown]
# #### If I want to get the row where temperature was minimum

# %%
df[df["temperature"] == df["temperature"].min()]
# Out:
#   event       day  temperature  windspeed
# 3  Snow  1/4/2017           24          7

# %% [markdown]
# #### If you want to get the row where temperature is minimum and only choose temperature and day column to be shown in the dataframe.

# %% [markdown]
# #### I thought that this method is correct but its not the reason being is
# - This is trying to index a Python list with a Pandas Series (a boolean mask).
# - ["temperature", "day"] is just a normal Python list.
# - I am then trying to index that list with:
#   - df["temperature"] == df["temperature"].min() This returns a Pandas series of True/False values one per row.
#   - ```
#     0    False
#     1    False
#     2    False
#     3     True
#     4    False
#     5    False
#     Name: temperature, dtype: bool
#     ```
# - ["temperature", "day"][<boolean_series>] because list indices must be integers or slices, not a Pandas series. This is the reason why I got this error in the cell below.

# %%
 df[["temperature","day"][df["temperature"]==df["temperature"].min()]] # wrong way
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-a8e99f889f57> in <module>
# ----> 1 df[["temperature","day"][df["temperature"]==df["temperature"].min()]] # wrong way
#
# TypeError: list indices must be integers or slices, not Series

# %%
df[df["temperature"] == df["temperature"].min()][["temperature", "day"]] # correct way
# Out:
#    temperature       day
# 3           24  1/4/2017

# %% [markdown]
# #### Select the row where windspeed is maximum and only show the day and windspeed column.

# %%
df[df["windspeed"] == df["windspeed"].max()][["day","windspeed"]] # correct way
# Out:
#         day  windspeed
# 1  1/2/2017          7
# 3  1/4/2017          7
