# %% [markdown]
# # Melt function in Pandas
# Melt function just like ```pivot``` function is used to reshape the dataFrame

# %%
import pandas as pd
import numpy as np
import itertools
from matplotlib import pyplot as plt
from typing import List, Optional

weather_df = pd.read_csv("/home/aditya/github/Deep-learning-prerequisite/pandas/dataset/weather_data_melt_func_demo.csv")
weather_df
# Out:
#          day  chicago  chennai  berlin  tokyo  sydney
# 0     Monday       32       75      41     55      65
# 1    Tuesday       30       77      43     58      68
# 2  Wednesday       28       75      45     53      64
# 3   Thursday       22       82      38     50      63
# 4     Friday       30       83      30     56      66
# 5   Saturday       20       81      45     54      67
# 6     Sunday       25       77      47     52      65

# %%
melted_df = pd.melt(weather_df,id_vars=["day"])
melted_df
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47
# 21     Monday    tokyo     55
# 22    Tuesday    tokyo     58
# 23  Wednesday    tokyo     53
# 24   Thursday    tokyo     50
# 25     Friday    tokyo     56
# 26   Saturday    tokyo     54
# 27     Sunday    tokyo     52
# 28     Monday   sydney     65
# 29    Tuesday   sydney     68
# ...

# %% [markdown]
# ### Huh? ... Interesting what do we have here
# ### Let's use pivot on this ```melted_df``` and see if my gut feeling right

# %%
pivoted_df = melted_df.pivot(index="day",columns="variable",values="value")
pivoted_df
# Out:
# variable   berlin  chennai  chicago  sydney  tokyo
# day
# Friday         30       83       30      66     56
# Monday         41       75       32      65     55
# Saturday       45       81       20      67     54
# Sunday         47       77       25      65     52
# Thursday       38       82       22      63     50
# Tuesday        43       77       30      68     58
# Wednesday      45       75       28      64     53

# %% [markdown]
# ### I knew it! ```pd.melt()``` function is nothing but opposite to ```df.pivot()``` function.
# ### Theory:
# - ```pd.melt()``` this function reshapes a DataFrame by converting columns into rows.
# - Wide format -> many columns for variable
# - Long format -> fewer columns, but more rows (tidy)
# #### What is ```pd.melt()```:
# - Your columns represent variable names (like years, months, metrics) instead of values.
# - You want to prepare data for plotting (most plotting libraries prefer long format).
# - You want to normalize messy spreadsheets into a standard structure.
# #### When not to use ```pd.melt()```:
# - Your data is already in long/tidy format.
# - You want a pivoted summary (example, aggregating sales per product).
# - You need aggregations/grouping -> use ```pivot_table``` instead
# ### Analysis
# ```pd.melt()``` function is also used to rehape the dataFrame just like the ```pivot``` function.
# - First argument taken by this function is the dataFrame.
# - Second argument taken by this function is ```id_vars[]```. The id variables is basically the thing that you want in your x axis in other words you pass in the columns that you want to keep intact after the rehaping of the dataFrame is complete.

# %% [markdown]
# #### How to set variable name and value name in melt function

# %%
melt_df = pd.melt(weather_df,id_vars=["day"],var_name="city",value_name="temperature")
melt_df
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47
# 21     Monday    tokyo           55
# 22    Tuesday    tokyo           58
# 23  Wednesday    tokyo           53
# 24   Thursday    tokyo           50
# ...

# %% [markdown]
# ## Example 1: Sales by year

# %% [markdown]
# ### Generate data

# %%
def generate_sales_data(products:List[str]=None, 
                        start_year:int=None, 
                        end_year:int=None, 
                        seed:int=None)->pd.DataFrame:
    # check if the arguments passed in this function is None or not
    if not products:
        raise ValueError("products is required!")
    if not start_year:
        raise ValueError("start_year is required!")
    if not end_year:
        raise ValueError("end_year is required!")
    if not seed:
        raise ValueError("seed is required!")
        
    # check the type of each arguments that is passed into this function
    if not isinstance(products,list):
        raise TypeError("products must be of type list")
    if not isinstance(start_year,int):
        raise TypeError("start_year must be of type int")
    if not isinstance(end_year,int):
        raise TypeError("end_year must be of type int")
    if not isinstance(seed,int):
        raise TypeError("seed must be of type int")
    
    np.random.seed(seed)  # for reproducibility
    
    # Years as columns
    years = list(map(str, range(start_year, end_year + 1)))
    
    # Random sales data between 100 and 5000
    data = {year: np.random.randint(100, 5000, size=len(products)) for year in years}
    
    # Build DataFrame
    df = pd.DataFrame(data)
    df.insert(0, "product", products)  # insert product column at start
    
    return df

# %%
products = [f"Product_{i}" for i in range(1, 31)] 
start_year=2004
end_year=2025
seed=42
sales_df = generate_sales_data(products,start_year,end_year,seed)
sales_df
# Out:
#        product  2004  2005  2006  2007  2008  2009  2010  2011  2012  ...  \
# 0    Product_1   960  1999  3943  3661  1159  3843  3031   723  3877  ...
# 1    Product_2  3872  1367  1600  2378  1822  1595   297  1116  2969  ...
# 2    Product_3  3192  1628  4898  3199  3414  3404  2030  3743  3334  ...
# 3    Product_4   566  3302   261   300  3257  3863  3682  2149  3891  ...
# 4    Product_5  4526  3656  4397  4975  2725  1953   708  3823  1056  ...
# 5    Product_6  3544  3990  2081  3204  2829  4759  3372  4648  4167  ...
# 6    Product_7  3271   746  1095  4698  1697  1391  1247  3208   260  ...
# 7    Product_8  3019  2988  3442  2554  3160  3681  4382  4190  4593  ...
# 8    Product_9   230  2535  4651  3745  2793  3557  3497  2156  1400  ...
# 9   Product_10  1785   700  3898   904  4991  1736  2611  3270  4087  ...
# 10  Product_11   869  2463  1375  2831  3727  3796  1894  1782  1627  ...
# 11  Product_12  2491  2161  1116  2873  1463  3099   759  2355  1318  ...
# ...

# %% [markdown]
# ### Apply melt function

# %%
melted_sales = pd.melt(sales_df,id_vars=["product"],var_name="year",value_name="sales")
melted_sales
# Out:
#         product  year  sales
# 0     Product_1  2004    960
# 1     Product_2  2004   3872
# 2     Product_3  2004   3192
# 3     Product_4  2004    566
# 4     Product_5  2004   4526
# ..          ...   ...    ...
# 655  Product_26  2025   2914
# 656  Product_27  2025   3474
# 657  Product_28  2025   3378
# 658  Product_29  2025   1352
# 659  Product_30  2025   4081
#
# [660 rows x 3 columns]

# %% [markdown]
# ### Apply groupby function

# %%
grouped_sales_df=melted_sales.groupby("product")
grouped_sales_df

# %% [markdown]
# ### Plot the data using matplotlib

# %%
# create a list of colors
color_list = ["green","purple","red","magenta","blue","yellow","orange"]
# create a list of line styles
linestyle_list= ["-","--",":","-.",(0,(5,1,5,1)),(0,(5,10))]

# create a cyclic iterator for color_list
color_cycle = itertools.cycle(color_list)
# create a cyclic iterator for linestyle_lits
linestyle_cycle = itertools.cycle(linestyle_list)

plt.figure(figsize=(12,6))
for product,df in grouped_sales_df:
    plt.plot(df["year"],df["sales"],marker="o",color=next(color_cycle),linestyle=next(linestyle_cycle),label="product")
plt.legend()
plt.tight_layout()
plt.title("Sales trend by products")
plt.show()

# %% [markdown]
# ### The data looks messy Lets use bar graph

# %%
plt.figure(figsize=(12,6))
for product,group in grouped_sales_df:
    plt.figure(figsize=(12,6))
    plt.bar(group["year"],group["sales"],color="orange")
    plt.title(f"Sales trend for {product}")
    plt.xlabel("Year")
    plt.ylabel("Sales")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Before we are able to plot the data using a heatmap we need to set the product column as an index into this dataFrame

# %%
heatmap_sales_df = melted_sales.set_index("product")
heatmap_sales_df
# Out:
#             year  sales
# product
# Product_1   2004    960
# Product_2   2004   3872
# Product_3   2004   3192
# Product_4   2004    566
# Product_5   2004   4526
# ...          ...    ...
# Product_26  2025   2914
# Product_27  2025   3474
# Product_28  2025   3378
# Product_29  2025   1352
# Product_30  2025   4081
#
# [660 rows x 2 columns]

# %%
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(heatmap_sales_df, annot=True, fmt="d", cmap="Blues")
plt.title("Sales Heatmap (Products vs Years)")
plt.xlabel("Product")
plt.ylabel("Year")
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 import seaborn as sns
#       2 plt.figure(figsize=(12,6))
# ----> 3 sns.heatmap(heatmap_sales_df, annot=True, fmt="d", cmap="Blues")
#       4 plt.title("Sales Heatmap (Products vs Years)")
#       5 plt.xlabel("Product")
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
# ...

# %% [markdown]
# #### ```TypeError: Image data of dtype object cannot be converted to float``` Analysis:
# This error happens because my ```heatmap_sales_df``` is in long format (with columns: ```product```, ```year```, ```sales```). <br>
# But ```sns.heatmap()``` expects a wide matrix (rows x columns numeric grid). <br>
# That means you need to pivot the data first so that:
# - Rows = products
# - Columns = years
# - Values =  sales

# %% [markdown]
# ## Example 2: Temperature by Month

# %% [markdown]
# ### Generate data

# %%
def generate_weather_data(
        city_list:List[str]=None,
        start_month:str=None,
        end_month:str=None,
    )-> pd.DataFrame:
    # Default months mapping
    months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
              "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
    
    # Ensure the inputs are valid
    if city_list is None or not city_list:
        raise ValueError("city_list must contain at least one city")
    if not start_month:
        raise ValueError("start_month required!")
    if not end_month:
        raise ValueError("end_month required!")
    if start_month not in months or end_month not in months:
        raise ValueError("start_month and end_month must be valid month abbreviations.")

    # Ensure that the argument type are as expected
    if not isinstance(city_list,list):
        raise TypeError("city_lits must be of type list")
    if not isinstance(start_month,str):
        raise TypeError("start_month must be of type str")
    if not isinstance(end_month,str):
        raise TypeError("end_month must be of type str")


    # Get the month range
    start_idx = months.index(start_month)
    end_idx = months.index(end_month) + 1
    selected_months = months[start_idx:end_idx]

    # Generate random realistic temperature in degree celcius
    data = {}
    for city in city_list:
        # Hotter cities
        if city.lower() in ["delhi","jaipur","lucknow"]:
            temps = np.random.randint(10,42,size=len(selected_months))
        # coastal cities
        elif city.lower() in ["mumbai","chennai","kolkata"]:
            temps = np.random.randint(20,35,size=len(selected_months))
        # default case
        else: 
            temps = np.random.randint(5,35,size=len(selected_months))
        data[city] = temps

    # create a dataFrame
    df = pd.DataFrame(data,index=selected_months).T
    df.reset_index(inplace=True)
    df.rename(columns={"index":"city"},inplace=True)
    return df

# %%
weather_df = generate_weather_data(
    city_list=["Delhi", "Mumbai", "Chennai","Lucknow","Kanpur","Patna","Rajasthan","Ahmedabad","Surat"],
    start_month="Jan",
    end_month="Oct"
)
weather_df
# Out:
#         city  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct
# 0      Delhi   11   20   28   16   15   41   37   11   15   27
# 1     Mumbai   21   21   33   34   30   22   34   21   23   28
# 2    Chennai   25   20   27   34   31   33   26   29   22   20
# 3    Lucknow   14   38   13   19   33   26   19   26   37   29
# 4     Kanpur   28    9    6   10   25    6   17   34   15   15
# 5      Patna   20   15   23   19   29   27   27   20   15   26
# 6  Rajasthan   20   12    8   12    8   28   29    7    7   31
# 7  Ahmedabad   33   22   33   30   23   23   25    9   22   32
# 8      Surat   14   33   26   25   10    5    9   13   16   30

# %%
plt.figure(figsize=(14,6))
sns.heatmap(weather_df,annot=True,cmap="Blues")
plt.title("Temperature heatmap (cities vs months)")
plt.xlabel("Months")
plt.ylabel("Cities")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(14,6))
# ----> 2 sns.heatmap(weather_df,annot=True,cmap="Blues")
#       3 plt.title("Temperature heatmap (cities vs months)")
#       4 plt.xlabel("Months")
#
# File ~/miniconda3/envs/tensorflow/lib/python3.10/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %% [markdown]
# #### ```ValueError: could not convert string to float: 'Delhi'``` Analysis :

# %%
plt.figure(figsize=(14,6))
sns.heatmap(weather_df.set_index("city"),annot=True,cmap="Blues")
plt.title("Temperature heatmap (cities vs months)")
plt.xlabel("Months")
plt.ylabel("Cities")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Use melt to rehape dataFrame into long form.

# %%
melted_weather_df = weather_df.melt(id_vars=["city"],var_name="months",value_name="temperature")
melted_weather_df
# Out:
#          city months  temperature
# 0       Delhi    Jan           11
# 1      Mumbai    Jan           21
# 2     Chennai    Jan           25
# 3     Lucknow    Jan           14
# 4      Kanpur    Jan           28
# ..        ...    ...          ...
# 85     Kanpur    Oct           15
# 86      Patna    Oct           26
# 87  Rajasthan    Oct           31
# 88  Ahmedabad    Oct           32
# 89      Surat    Oct           30
#
# [90 rows x 3 columns]

# %% [markdown]
# ### Perform groupby operation on the dataFrame

# %%
grouped_weather_df = melted_weather_df.groupby("city")
grouped_weather_df

# %%
color_list = ["red","magenta","green","purple","yellow","blue","orange"]

color_cycle = itertools.cycle(color_list)

plt.figure(figsize=(14,8))
for city,df in grouped_weather_df:
    plt.plot(df["months"],df["temperature"],marker="o",label=city)
plt.xlabel("Month")
plt.ylabel("Temperature")
plt.legend()
plt.title("Monthly temperature by city")
plt.grid()
plt.show()
